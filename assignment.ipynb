# %%
name = "Rahul"
age = 21
city = "Jaipur"

print(name, age, city)
# Out:
# Rahul 21 Jaipur

# %%
print("2026", "05", "28", sep="-")
# Out:
# 2026-05-28

# %%
name = input("Enter your name: ")

print("Hello", name)
# Out:
# Hello rohan

# %%
name = input("Please enter your name: ")

print("Welcome to Python,", name + "!")
# Out:
# Welcome to Python, rohan!

# %%
name = input("Enter your name: ")
age = input("Enter your age: ")

print("Name:", name, "| Age:", age, sep=" ")
print("Thank you for using Python.", end=" ")
print("Have a nice day!")
# Out:
# Name: rohan | Age: 19
# Thank you for using Python. Have a nice day!
