# %%
name = input("name of student:")
student_class = input("class of student:")
m1 = int(input("first subject marks:"))
m2 = int(input("second subject marks:"))
m3 = int(input("third subject marks:"))
m4 = int(input("fourth subject marks:"))
m5 = int(input("five subject marks:"))
total = m1 + m2 + m3 + m4 + m5
percentage = total/5
print("result")
print("name=",name)
print("student_class=",student_class)
print("toltal=",total)
print("percentage=",percentage)
# Out:
# result
# name= rohan
# student_class= 12
# toltal= 410
# percentage= 82.0

# %%
str1 = input("first string:")
str2 = input("second string:")
result = str1+" "+str2
print("concatenate:",result)
print("upper:",result.upper())
print("lower:",result.lower())
print("endswith:",result.endswith("a"))
print("title:",result.title())
print("swapcase:",result.swapcase())
print("capitalize:",result.capitalize())
print("center:",result.center(40))
print("count:",result.count("a"))
print("find:",result.find("a"))
print("isalnum:",result.isalnum())
print("isdigit:",result.isdigit())
print("isnumeric:",result.isnumeric())
print("isspace:",result.isspace())
print("replace:",result.replace("a","e"))
# Out:
# concatenate: rohan is a boy human are mortal
# upper: ROHAN IS A BOY HUMAN ARE MORTAL
# lower: rohan is a boy human are mortal
# endswith: False
# title: Rohan Is A Boy Human Are Mortal
# swapcase: ROHAN IS A BOY HUMAN ARE MORTAL
# capitalize: Rohan is a boy human are mortal
# center:     rohan is a boy human are mortal
# count: 5
# find: 3
# isalnum: False
# isdigit: False
# isnumeric: False
# isspace: False
# replace: rohen is e boy humen ere mortel

# %%
x = 10

print("Initial value of x =", x)

x += 5
print("After += 5 :", x)

x -= 3
print("After -= 3 :", x)

x *= 2
print("After *= 2 :", x)

x /= 4
print("After /= 4 :", x)

x %= 3
print("After %= 3 :", x)

x **= 2
print("After **= 2 :", x)

x //= 2
print("After //= 2 :", x)
# Out:
# Initial value of x = 10
# After += 5 : 15
# After -= 3 : 12
# After *= 2 : 24
# After /= 4 : 6.0
# After %= 3 : 0.0
# After **= 2 : 0.0
# After //= 2 : 0.0

# %%
name = input("Enter student name: ")
student_class = input("Enter class: ")

m1 = int(input("Enter marks of Subject 1: "))
m2 = int(input("Enter marks of Subject 2: "))
m3 = int(input("Enter marks of Subject 3: "))
m4 = int(input("Enter marks of Subject 4: "))
m5 = int(input("Enter marks of Subject 5: "))

total = m1 + m2 + m3 + m4 + m5
percentage = total / 5

if percentage >= 60:
    grade = 'A'
elif percentage >= 50 and percentage < 60:
    grade = 'B'
elif percentage >= 40 and percentage < 50:
    grade = 'C'
elif percentage >= 33 and percentage < 40:
    grade = 'D'
else:
    grade = 'Fail'

print("\nRESULT")
print("Name :", name)
print("Class :", student_class)
print("Total Marks :", total)
print("Percentage :", percentage)
print("Grade :", grade)
# Out:
# RESULT
# Name : rohan
# Class : 12
# Total Marks : 436
# Percentage : 87.2
# Grade : A
